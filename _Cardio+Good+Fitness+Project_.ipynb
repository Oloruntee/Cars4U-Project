# %% [markdown]
# Name : Seun Holiness OLORUNTOBA
#
# Project : Project 1 - Data Analysis on Cardio Fitness

# %% [markdown]
# Objective - Preliminary Data Analysis.
# Explore the dataset and practice extracting basic observations about the data. The idea is for you to get comfortable working in Python.
#
# You are expected to do the following :
# Come up with a customer profile (characteristics of a customer) of the different products
# Perform uni-variate and multi-variate analyses
# Generate a set of insights and recommendations that will help the company in targeting new customers
#
# Explore the dataset to identify differences between customers of each product. You can also explore relationships between the different attributes of customers. You can approach it from any other line of questioning that you feel could be relevant for the business.
#
# Minimum Steps for exploration:
#
# Importing the dataset into Python & understanding the structure of the dataset
# Basic summary of data and graphical exploration
# Observations from the dataset
#
# 1.Product - the model no. of the treadmill
# 2.Age - in no of years, of the customer
# 3.Gender - of the customer
# 4.Education - in no. of years, of the customer
# 5.Marital Status - of the customer
# 6.Usage - Avg. # times the customer wants to use the treadmill every week
# 7.Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# 8.Income - of the customer
# 9.Miles- expected to run

# %%
#import python libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
sns.set(style="darkgrid") # Shows the background grid 
warnings.filterwarnings('ignore')   # to avoid warnings

# %%
# Reading datasets by using read_csv from pandas package
df_Cardio = pd.read_csv('CardioGoodFitness.csv')

# %%
df_Cardio.head() # view the top five rows of the dataset
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# Check info about the dataset(info,shape, describe)

# %%
df_Cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
# Product          180 non-null object
# Age              180 non-null int64
# Gender           180 non-null object
# Education        180 non-null int64
# MaritalStatus    180 non-null object
# Usage            180 non-null int64
# Fitness          180 non-null int64
# Income           180 non-null int64
# Miles            180 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 12.7+ KB

# %% [markdown]
# Observation:
# From above it confirms there are 180 entries with datatype information as follows; Age, Education, Usage,Fitness, Income, Miles are intergers, while Product,Gender and MaritalStatus are 3 string data types:

# %%
df_Cardio.shape # To confirm the numbers of rows and colums
# Out:
# (180, 9)

# %% [markdown]
# Observation:
# There are 180 rows and 9 columns

# %%
df_Cardio.describe() # To confirm the statistical information of the dataset
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# Observation:
# 1. No evidence of missing values based on the consistency of the counts at 180 which is the number of enteries.
# 2. The Minimum age of the Cutomers was 18 years while the maximum age was 50 years
# 3. The Education level between the Median (50th percentile) and 75th Percentile are the same - 16
# 4. The Usage and Fitness between 25th percentile and 50 percentile are the same -3

# %%
#Getting all the columns name 
df_Cardio.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
#To explore categorical features 
print(df_Cardio.Product.nunique())
print(df_Cardio.Gender.nunique())
print(df_Cardio.MaritalStatus.nunique())
# Out:
# 3
# 2
# 2

# %% [markdown]
# Observation:
# There are 3 unique products
# There are 2 uniques Sexes
# There are 2 uniques MaritalStatus

# %%
#To know the exact uniquesness of the features 
print(df_Cardio.Product.unique())
print(df_Cardio.Gender.unique())
print(df_Cardio.MaritalStatus.unique())
# Out:
# ['TM195' 'TM498' 'TM798']
# ['Male' 'Female']
# ['Single' 'Partnered']

# %% [markdown]
# Observation:
# 1. There are three models of the product(threadmills)
# 2. There are 2 sexes
# 3. There are 2 MaritalStatus

# %%
#Group the dataset based on product, sum and explore the dataset
df_Product_group = df_Cardio.groupby('Product').mean() #Mean would give a better discription of the exploration

# %%
print(df_Product_group)
# Out:
#            Age  Education     Usage  Fitness     Income       Miles
# Product
# TM195    28.55  15.037500  3.087500   2.9625  46418.025   82.787500
# TM498    28.90  15.116667  3.066667   2.9000  48973.650   87.933333
# TM798    29.10  17.325000  4.775000   4.6250  75441.575  166.900000

# %% [markdown]
# Observation:
# 1. The average Age, Education, Usage, Fitness, Income and Miles of those using product TM195 and TM498 are closer to each other compared to those using TN798.

# %% [markdown]
# Commence Univariate Exploration of the Dataset by considering each of the 9 features. The Univariate used were: Countplot, Stripplot and Swarmplot.

# %%
#Total number of each unique product(Univariate) 
sns.countplot(x = df_Cardio['Product'])
plt.show()

# %% [markdown]
# Obervations :
# 1. TM195 - 80 products
# 2. TM498 - 60 products
# 3. TM798 - 40 products
#
# Therefore, TM 195 is the largest number of treadmills that was purchased by the people.
# Even though this is the highest products we need to verify if that is true among different Genders, MaritalStatus and other features.

# %%
#Usage of product by Gender (Univariate)
sns.countplot(df_Cardio['Product'], hue = df_Cardio['Gender'])
plt.show()

# %% [markdown]
# Observation:
# 1. TM195 was purchased at the same rate by both male and female(40/40).
# 2. TM798 was purchased highly by male, the male account for almost 82% purchase of this product.
# 3. TM498 purchase is almost same between male and female with just few differencse, male having higher by less than 5%.

# %%
#Usage of product by MaritalStatus(Univariate)
sns.countplot(df_Cardio['Product'], hue = df_Cardio['MaritalStatus'])
plt.show()

# %% [markdown]
# Observation:
# 1. All the three products were purchased more by Partnered than Singles

# %%
#Use pointplot to understand the variation of income with product.
sns.stripplot(x="Product", y="Income", data=df_Cardio)
plt.xticks(rotation=90) # To rotate the x axis labls
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# Observation:
# 1. High income earners purchase more of TM798 products
# 2. Lower income earners purchase more of TM195 & TM498 products
# 3. The highest income for TM195 & TM498(70,000) is still less than the mean of TM798 which is 75442

# %%
#Use stripplot to understand the variation of Miles with Product.
sns.stripplot(x="Product", y="Miles", data=df_Cardio)
plt.xticks(rotation=90) # To rotate the x axis
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# Observation:
#     1. TM798 has the highest Miles and Range of Miles too, the range(Max-Min) is the highest.
#     2. TM195 and TM498 has lower miles but TM498 has the least Miles but has a higher mile than TM195

# %%
#Use stripplot to understand the variation of Usage with Product.
sns.swarmplot(x = "Product", y="Usage", data=df_Cardio)
plt.xticks(rotation=90) # To rotate the x axis
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
1. TM798 customers has the highest Usage per week among the 3 category of treadmills this is expected because its usage would be far 
    easier because it is used by more by high income customers which means it would be expensive. 
    
2. TM 195 has higher frequency in terms of the number of customers with usage but TM798 has cutomers with the highest usage per week.

# %%
#Use stripplot to understand the variation of Fitness with Product.
sns.swarmplot(x = "Product", y="Fitness", data=df_Cardio)
plt.xticks(rotation=90) # To rotate the x axis
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# 1. TM798 has the highest number of Customers with highest fitness ratings compared to the other two treadmills
# 2. TM195 has the highesst number of customers but only 2 has highest fitness rating of 5 as compared to TM798
# 3. TM195 has the highest range and spread of Customers in terms of fitness ratings.

# %%
#Use stripplot to understand the variation of Age with Product.
sns.swarmplot(x = "Product", y="Age", data=df_Cardio)
plt.xticks(rotation=90) # To rotate the x axis
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# Observation:
# TM195 has the highest range in terms of customers age spread, as compared to the other treadmills
# The highest age of the customers is 50years and he purchases TM195 and the least age also purchases TM195 Threadmill.

# %%
#Use stripplot to understand the variation of Age with Product.
sns.swarmplot(x = "Product", y="Education", data=df_Cardio)
plt.xticks(rotation=90) # To rotate the x axis
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %% [markdown]
# Observation:
# The highly Educated Customers purchase more of TM798

# %% [markdown]
#  Multivariate Eploratory Data Analysis, use Implot, Pairplot and Heatmap

# %%
#Use implot to check the relationship between Product, Fitness, Gender, Usage and MaritalStatus(Multivariate)
plt.figure(figsize=(70,40)) #To make the size bigger
sns.lmplot(x='Product',y='Fitness',data=df_Cardio,fit_reg=False,hue='Gender',row='Usage',col='MaritalStatus')
plt.show()

# %% [markdown]
# Observations:
# 1. For singles - customers with the lower usage per week-2 and lower fitness
#     ratings- 2 & 3 are majorly female singles and they never purchase TM798 treadmill.
# 2. The Partnered - female partnered customers still dominate the lower usage per week- 2
#     and lower fitness rating- 2 & 3 eventhough there is a presence of 25% of male
#     partnered.
# 3. For customers with usage of 3 times per week, the female single still dominate except
#    25% of it occupied by Male single with the highest fitness rating and is the
#     only one using TM798
# 4. There are more high usage among the partnered than singles, as partnered
#     accounted for about 75% of usage >6
# 5. The lowest fitness rating ever had by TM798 is a 3.0 while the other threadmill
#     both had 1 as their lowest rating.
# 6. All customers that had usage >6 both single and partnered uses TM798 threadmill but they
#     are 75% Male dominated
# 7. The least fitness rating for usage >6 is a 4 both partnered and single and those with
#     usage of 7 times per day have 5 ratings on fitness.
# 8. Almost 80% of customers that have 5 fitness ratings uses TM798
# 9. No customer using the TM498 achieved the 5 star rating
# 10. 14% of customers using the TM195 achieved 5 ratings in fitness

# %%
#Pairplot (Multivariate Plot)
sns.pairplot(df_Cardio) # To view the correlation of the different columns(features)
plt.show()

# %%
correlation = df_Cardio.corr() # creating a 2-D Matrix with correlation plots
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation, annot=True, cmap='YlGnBu', vmin=-1, vmax=1) # Producing an Heatmap from the correlation

# %% [markdown]
# Observations:
# 1. The only moderatly high correlation that Age has is with income and does not have high correlation with other feature.
# 2. Education and income have moderately high correlation as expected and has no high correlation with any other features.
# 3. Usage has high correlation with Miles as expected(The more you use the more the mileage), also moderately high with Fitness as expected.
# 4. Fitness has high positive correlation with miles(as expected the more miles on treadmill the better the fitness), also fitness has moderately high correlation with usage  and slightly with income.
# 5. Income has relatively moderate correlation with all the features, which means to a reasonable extend the income of people define almost all the features.
# 6. Miles has high positive correlation with Usage and Fitness as expected(Since the more Miles the more Usage and Fitness)
#    and moderately with income.
# 7. Age and Education have no correlation with any feature except moderate correlation with income.

# %%
Customer Profile of each product:
    1. TM195 
        a. This is common with people that has lower income,lower usage  fitness rating and lower Miles. 
        b. Also, another profile for these customers is that, they are less educated 
        compared to TM798. 
        c. The customers are both male and female at equal purchase by sex.
        d. This product is common with both partnered and single MaritalStatus, but the higher percentage 
        of the customers are partnered.
        
    2. TM498
        a. This is common with people that has lower income,lower usage per week, 
        ,lower fitness rating and lower Miles. 
        b. Also, another profile for these customers is that, they are less educated 
        compared to TM798.
        c. The customers are both male and female with slightly higher number of male
        than female
        d. This is common with both partnered and single, but the higher percentage 
        of the customers are partnered.
        
    3. TM798
        a. This is common with customers that has higher income, higher usage per week 
        high fitness rating and higher Miles.
        b. Also, another profile for these customers is that, they are more educated 
        compared to customers of TM195 & TM498
        c. The customers are both male and female with a far higher number of male
        than female.
        d. This is common with both partnered and single, but the higher percentage 
        of the customers are partnered.

# %% [markdown]
# Univate and Multivariate - Completed above

# %%
Generate a set of insights and recommendations that will help the company in targeting new customers:

1. Insight: 
The customers profile for both TM195 and TM498 are almost the same, which means the products are almost at the same level of acceptability to the two customer profiles.

Recommendation:
Since the two treadmills have almost the same customers profile, it would be good to use a recommender system to advertise TM498 to customers who shows interest in TM195 and vice versa, since there prices may differ. This would help increase the customers as advertizing the other models with almost same customers profile will ensure the customer are retained rather than losing them. 

2. Insight: 
The partnered purchase all the products(TM195, TM498 & TM798) far more than the single and the partnered have more high usage than the singles.  

Recommendation:
1. Conduct an advert or campaign on the value of fitness for singles and the need to keep healthy even before marriage. 
2. Give some incentives or coupon for singles that are interested in buying any of the treadmill this will create more interest among single. 
3. Nominate a youth ambassador who can serve as the advocate of the products among young people and singles generally. 

3. Insight:
The high income customers buy TM798 far more than other products 

Recommendation: 
a. Since more high income customers like this product, develop a means to keep them like loyalty card and other high profile marketing methods.
b. Also, to get more customers from the medium to low income earners to buy this product, develop a marketing or campaign system to focus on the value of the TM798 threadmill in terms of fitness, miles, usage etc, so as to attract some customers more to the new product. 

4. Insight: 
More educated customers purchase TM 798 compared to the other two(TM195, TM498)

Recommendation:
a. Ensure the adverts to the cutomers intending to purchase TM798 is tailored towards the educated and well learned people which can be made more professional and adverts placement is done on News, Webinar etc where more educated customers visit and interact.
b. In addition to the above, for the less educated more of informal advertisement should be done which can be easily understood by the people with less education and they can easily connect to it. 

5.Insight:
Miles,Usage and Fitness are highly correlated - Fitness is highly dependent on  Miles and Usage. 

Recommendation: 
The correlation between Fitness and Miles & Usage should be used to advertise to other customers who may be fat or feel unfit. Advertisisng the value of the treadmill from usage and miles as a means of being fit will attract new customers who want to be fit. 

6. Insight 
The female customers dominate the lowest usage per week feature in the dataset

Recommendation: 
Develop a special package or campaign to encourage female fitness, maybe it can be called "Female Fitness Program", which can encourage them to increase their usage of the treadmill and therefore increase their interest to purchase the high rated treadmill the TM798, which most of the lower usage do not purchase.
